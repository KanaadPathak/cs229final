# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from pandas.tools.plotting import scatter_matrix

# %%
# Load CSV using Pandas
df = pd.read_csv('data/train.csv')
print(df.shape)
# Out:
# (990, 194)

# %%
df.head(3)
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
#
#     margin5   margin6   margin7  margin8    ...      texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0    ...       0.007812        0.0
# 1  0.025391  0.001953  0.019531      0.0    ...       0.000977        0.0
# 2  0.003906  0.005859  0.068359      0.0    ...       0.154300        0.0
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
#
# ...

# %%
list(df.columns.values)
# Out:
# ['id',
#  'species',
#  'margin1',
#  'margin2',
#  'margin3',
#  'margin4',
#  'margin5',
#  'margin6',
#  'margin7',
#  'margin8',
#  'margin9',
#  'margin10',
#  'margin11',
#  'margin12',
#  'margin13',
#  'margin14',
#  'margin15',
#  'margin16',
#  'margin17',
#  'margin18',
#  'margin19',
#  'margin20',
#  'margin21',
#  'margin22',
#  'margin23',
#  'margin24',
#  'margin25',
#  'margin26',
#  'margin27',
#  'margin28',
#  'margin29',
#  'margin30',
#  'margin31',
#  'margin32',
#  'margin33',
#  'margin34',
#  'margin35',
#  'margin36',
#  'margin37',
#  'margin38',
#  'margin39',
#  'margin40',
#  'margin41',
#  'margin42',
#  'margin43',
#  'margin44',
#  'margin45',
#  'margin46',
#  'margin47',
#  'margin48',
#  'margin49',
#  'margin50',
#  'margin51',
#  'margin52',
#  'margin53',
#  'margin54',
#  'margin55',
#  'margin56',
#  'margin57',
#  'margin58',
#  'margin59',
#  'margin60',
#  'margin61',
#  'margin62',
#  'margin63',
#  'margin64',
#  'shape1',
#  'shape2',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=990, step=1)

# %%
textures = df.filter(['texture1', 'texture2', 'texture3'])
scatter_matrix(textures)
plt.show()

# %%
margins = df.filter(['margin1', 'margin2', 'margin3', 'margin4'])
scatter_matrix(margins)
plt.show()

# %%
selected = ["shape%i" % i for i in range(1, 10)]
scatter_matrix(df.filter(selected))
plt.show()
